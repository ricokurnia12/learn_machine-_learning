# %%
from ipynb.fs.full.main import df_lencoder

df_lencoder.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from ipynb.fs.full.main import df_lencoder
#       3 df_lencoder.head()
#
# ImportError: cannot import name 'df_lencoder' from 'ipynb.fs.full.main' (unknown location)
